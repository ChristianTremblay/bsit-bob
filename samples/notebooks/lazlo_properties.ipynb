# %%
from bob.devices.hvac.fan import Fan
from bob.core import dump, clear, s223, p223
from bob.connections.electricity import *
from bob.property import QuantifiableObservableProperty
clear()



fan_template = {
    "params": {
        "label": "MyFan", 
        "comment": "A Big Fan",
        #"electricalInlet": Electricity_575V_60HzInletConnectionPoint,
        "amps": 10,
        "hp": 10,
        "rpm": 1770,
        "powerFactor": 1.4
    },
    "sensors": {},
    "contains": {},
}

f = Fan(config=fan_template)

# %%
f
# Out:
# <Fan MyFan at Naab5d8209c5e47ef974e25273e0734fb>

# %%
dump()
# Out:
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix s223: <http://data.ashrae.org/standard223#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# [] a s223:Device,
#         s223:Fan ;
#     rdfs:label "MyFan" ;
#     s223:airInlet _:Nb62b412a66c7421aab84e8f5ce7e5383 ;
#     s223:airOutlet _:N4abf968df8f743b694611ecae0b0e2ad ;
#     s223:amps _:N1f4f8e892e9c4704b94b91fdcf741eac ;
#     s223:electricalInlet _:Nd93fe6bedf7947baa686d1c98a7ee732 ;
#     s223:frame _:Nadb62f9a68b74db6ac6de0407dc6542b ;
#     s223:hasConnectionPoint _:N4abf968df8f743b694611ecae0b0e2ad,
#         _:Nb62b412a66c7421aab84e8f5ce7e5383,
#         _:Nd93fe6bedf7947baa686d1c98a7ee732 ;
#     s223:hasProperty _:N061791a28f6a47b0bf4939dada362391,
#         _:N12f28015fa9d43cc9a7986b187d51d84,
#         _:N1f4f8e892e9c4704b94b91fdcf741eac,
#         _:N69c3bad35222428aadfae8d9d072275c,
#         _:Nadb62f9a68b74db6ac6de0407dc6542b ;
#     s223:hp _:N12f28015fa9d43cc9a7986b187d51d84 ;
#     s223:powerFactor _:N061791a28f6a47b0bf4939dada362391 ;
#     s223:rpm _:N69c3bad35222428aadfae8d9d072275c ;
#     rdfs:comment "A Big Fan" .
# _:N061791a28f6a47b0bf4939dada362391 a s223:ObservableProperty,
#         s223:QuantifiableObservableProperty,
#         s223:QuantifiableProperty ;
#     s223:hasValue 1.4 .
# _:N12f28015fa9d43cc9a7986b187d51d84 a s223:ObservableProperty,
#         s223:QuantifiableObservableProperty,
#         s223:QuantifiableProperty ;
#     s223:hasValue 10.0 .
# _:N1f4f8e892e9c4704b94b91fdcf741eac a s223:ObservableProperty,
#         s223:QuantifiableObservableProperty,
#         s223:QuantifiableProperty ;
#     s223:hasValue 10.0 .
# _:N4abf968df8f743b694611ecae0b0e2ad a s223:ConnectionPoint,
#         s223:OutletConnectionPoint ;
#     rdfs:label "MyFan.airOutlet" ;
#     s223:hasDirection s223:Direction-Outlet ;
#     s223:hasMedium s223:Medium-Air .
# _:N69c3bad35222428aadfae8d9d072275c a s223:ObservableProperty,
#         s223:QuantifiableObservableProperty,
#         s223:QuantifiableProperty ;
#     s223:hasValue 1770.0 .
# _:Nadb62f9a68b74db6ac6de0407dc6542b a s223:ObservableProperty,
#         s223:QuantifiableObservableProperty,
#         s223:QuantifiableProperty ;
#     s223:hasValue 2.0 .
# _:Nb62b412a66c7421aab84e8f5ce7e5383 a s223:ConnectionPoint,
#         s223:InletConnectionPoint ;
#     rdfs:label "MyFan.airInlet" ;
#     s223:hasDirection s223:Direction-Inlet ;
#     s223:hasMedium s223:Medium-Air .
# _:Nd93fe6bedf7947baa686d1c98a7ee732 a s223:ConnectionPoint,
#         s223:InletConnectionPoint ;
#     rdfs:label "MyFan.electricalInlet" ;
#     s223:hasDirection s223:Direction-Inlet ;
#     s223:hasMedium s223:Medium-Electricity .
